# %%
import json
import pandas as pd

# %%
file_path1 = '/content/beats_pill_blk_data.json'
with open(file_path1, 'r') as file:
    data1 = json.load(file)

# %%
reviews_data1 = []
count1 = 0

for result in data1.get('results', []):
    asin = result.get('content', {}).get('asin')
    if asin is None:
        continue  # Skip if asin is missing

    for review in result.get('content', {}).get('reviews', []):
        count1 += 1
        try:
            review_info1 = {
                'review_id': review.get('id'),
                'product_id': asin,
                'title': review.get('title'),
                'author': review.get('author'),
                'rating': review.get('rating'),
                'content': review.get('content'),
                'timestamp': review.get('timestamp'),
                'profile_id': review.get('profile_id'),
                'is_verified': review.get('is_verified', False),
                'helpful_count': review.get('helpful_count', 0),
                'product_attributes': review.get('product_attributes', {}),
            }
            reviews_data1.append(review_info1)
        except KeyError as e:
            print(f"KeyError at review {count1}: {e}")
        except Exception as e:
            print(f"Error at review {count1}: {e}")

if reviews_data1:
    reviews_df1 = pd.DataFrame(reviews_data1)
else:
    print("No reviews data available.")

# %%
reviews_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           70 non-null     object
#  1   product_id          70 non-null     object
#  2   title               70 non-null     object
#  3   author              70 non-null     object
#  4   rating              70 non-null     int64
#  5   content             70 non-null     object
#  6   timestamp           70 non-null     object
#  7   profile_id          70 non-null     object
#  8   is_verified         70 non-null     bool
#  9   helpful_count       70 non-null     int64
#  10  product_attributes  70 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 5.7+ KB

# %%
reviews_df1.head()
# Out:
#         review_id  product_id  \
# 0  R2LVX0OMHFZX0L  B0D4SX9RC6
# 1  R1VF3BHPT5C61N  B0D4SX9RC6
# 2  R2YFCRSC298TS7  B0D4SX9RC6
# 3  R1DKVIHXE9RZUS  B0D4SX9RC6
# 4   RLRUIVAAGZ3EN  B0D4SX9RC6
#
#                                                title      author  rating  \
# 0                    5.0 out of 5 stars Sounds great  Hollywoody       5
# 1                             5.0 out of 5 stars JBL     Michael       5
# 2                      5.0 out of 5 stars I love it!  William G.       5
# 3  2.0 out of 5 stars Must me rejects from a real...      lady b       2
# 4               5.0 out of 5 stars A gift for my dad    Jacky K.       5
#
#                                              content  \
# 0  I just sent back my JBL Flip because it had di...
# 1  They are a great value. The sound is awesome. ...
# 2  The sound quality is amazing, it’s easy to pai...
# 3  This speaker must have come from failed qualit...
# 4  Sound quality is good. it can get pretty loud ...
#
#                                        timestamp  \
# 0  Reviewed in the United States January 9, 2025
# 1  Reviewed in the United States January 8, 2025
# 2  Reviewed in the United States January 8, 2025
# 3  Reviewed in the United States January 8, 2025
# 4  Reviewed in the United States January 8, 2025
#
#                      profile_id  is_verified  helpful_count product_attributes
# 0  AHCSV6WLXXA2EXLWOMLMB2FZBKEQ        False              0                 {}
# 1  AHUWZOAL676ROBBD7SRER6KYJBKA        False              0                 {}
# 2  AGY6HYEBNUXQXEA7GPOZYZRRY3FQ        False              0                 {}
# 3  AH3ZDVKGDOBN2OI6CH5WLVMN3JMA        False              0                 {}
# 4  AFYJOKU2NXNZ5QCVTJCRGJBFUIVA        False              0                 {}

# %%
file_path2 = '/content/beats_pill_red_data.json'
with open(file_path2, 'r') as file:
    data2 = json.load(file)

# %%
reviews_data2 = []
count2 = 0

for result in data2.get('results', []):
    asin = result.get('content', {}).get('asin')
    if asin is None:
        continue  # Skip if asin is missing

    for review in result.get('content', {}).get('reviews', []):
        count2 += 1
        try:
            review_info2 = {
                'review_id': review.get('id'),
                'product_id': asin,
                'title': review.get('title'),
                'author': review.get('author'),
                'rating': review.get('rating'),
                'content': review.get('content'),
                'timestamp': review.get('timestamp'),
                'profile_id': review.get('profile_id'),
                'is_verified': review.get('is_verified', False),
                'helpful_count': review.get('helpful_count', 0),
                'product_attributes': review.get('product_attributes', {}),
            }
            reviews_data2.append(review_info2)
        except KeyError as e:
            print(f"KeyError at review {count2}: {e}")
        except Exception as e:
            print(f"Error at review {count2}: {e}")

if reviews_data2:
    reviews_df2 = pd.DataFrame(reviews_data2)
else:
    print("No reviews data available.")

# %%
reviews_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           35 non-null     object
#  1   product_id          35 non-null     object
#  2   title               35 non-null     object
#  3   author              35 non-null     object
#  4   rating              35 non-null     int64
#  5   content             35 non-null     object
#  6   timestamp           35 non-null     object
#  7   profile_id          35 non-null     object
#  8   is_verified         35 non-null     bool
#  9   helpful_count       35 non-null     int64
#  10  product_attributes  35 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 2.9+ KB

# %%
reviews_df2.head()
# Out:
#         review_id  product_id  \
# 0  R2LVX0OMHFZX0L  B0D4STD5ZC
# 1  R1VF3BHPT5C61N  B0D4STD5ZC
# 2  R2YFCRSC298TS7  B0D4STD5ZC
# 3  R1DKVIHXE9RZUS  B0D4STD5ZC
# 4   RLRUIVAAGZ3EN  B0D4STD5ZC
#
#                                                title      author  rating  \
# 0                    5.0 out of 5 stars Sounds great  Hollywoody       5
# 1                             5.0 out of 5 stars JBL     Michael       5
# 2                      5.0 out of 5 stars I love it!  William G.       5
# 3  2.0 out of 5 stars Must me rejects from a real...      lady b       2
# 4               5.0 out of 5 stars A gift for my dad    Jacky K.       5
#
#                                              content  \
# 0  I just sent back my JBL Flip because it had di...
# 1  They are a great value. The sound is awesome. ...
# 2  The sound quality is amazing, it’s easy to pai...
# 3  This speaker must have come from failed qualit...
# 4  Sound quality is good. it can get pretty loud ...
#
#                                        timestamp  \
# 0  Reviewed in the United States January 9, 2025
# 1  Reviewed in the United States January 8, 2025
# 2  Reviewed in the United States January 8, 2025
# 3  Reviewed in the United States January 8, 2025
# 4  Reviewed in the United States January 8, 2025
#
#                      profile_id  is_verified  helpful_count product_attributes
# 0  AHCSV6WLXXA2EXLWOMLMB2FZBKEQ        False              0                 {}
# 1  AHUWZOAL676ROBBD7SRER6KYJBKA        False              0                 {}
# 2  AGY6HYEBNUXQXEA7GPOZYZRRY3FQ        False              0                 {}
# 3  AH3ZDVKGDOBN2OI6CH5WLVMN3JMA        False              0                 {}
# 4  AFYJOKU2NXNZ5QCVTJCRGJBFUIVA        False              0                 {}

# %%
combined_df = pd.concat([reviews_df1, reviews_df2], ignore_index=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           105 non-null    object
#  1   product_id          105 non-null    object
#  2   title               105 non-null    object
#  3   author              105 non-null    object
#  4   rating              105 non-null    int64
#  5   content             105 non-null    object
#  6   timestamp           105 non-null    object
#  7   profile_id          105 non-null    object
#  8   is_verified         105 non-null    bool
#  9   helpful_count       105 non-null    int64
#  10  product_attributes  105 non-null    object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 8.4+ KB

# %%
combined_df.head()
# Out:
#         review_id  product_id  \
# 0  R2LVX0OMHFZX0L  B0D4SX9RC6
# 1  R1VF3BHPT5C61N  B0D4SX9RC6
# 2  R2YFCRSC298TS7  B0D4SX9RC6
# 3  R1DKVIHXE9RZUS  B0D4SX9RC6
# 4   RLRUIVAAGZ3EN  B0D4SX9RC6
#
#                                                title      author  rating  \
# 0                    5.0 out of 5 stars Sounds great  Hollywoody       5
# 1                             5.0 out of 5 stars JBL     Michael       5
# 2                      5.0 out of 5 stars I love it!  William G.       5
# 3  2.0 out of 5 stars Must me rejects from a real...      lady b       2
# 4               5.0 out of 5 stars A gift for my dad    Jacky K.       5
#
#                                              content  \
# 0  I just sent back my JBL Flip because it had di...
# 1  They are a great value. The sound is awesome. ...
# 2  The sound quality is amazing, it’s easy to pai...
# 3  This speaker must have come from failed qualit...
# 4  Sound quality is good. it can get pretty loud ...
#
#                                        timestamp  \
# 0  Reviewed in the United States January 9, 2025
# 1  Reviewed in the United States January 8, 2025
# 2  Reviewed in the United States January 8, 2025
# 3  Reviewed in the United States January 8, 2025
# 4  Reviewed in the United States January 8, 2025
#
#                      profile_id  is_verified  helpful_count product_attributes
# 0  AHCSV6WLXXA2EXLWOMLMB2FZBKEQ        False              0                 {}
# 1  AHUWZOAL676ROBBD7SRER6KYJBKA        False              0                 {}
# 2  AGY6HYEBNUXQXEA7GPOZYZRRY3FQ        False              0                 {}
# 3  AH3ZDVKGDOBN2OI6CH5WLVMN3JMA        False              0                 {}
# 4  AFYJOKU2NXNZ5QCVTJCRGJBFUIVA        False              0                 {}

# %%
#combined_df.to_csv('beatspill_data.csv', index=False)
