# %%
import json
import pandas as pd

# %%
file_path1 = '/content/doss_soundbox_touch_blk_data.json'
with open(file_path1, 'r') as file:
    data1 = json.load(file)

# %%
reviews_data1 = []
count1 = 0

for result in data1.get('results', []):
    asin = result.get('content', {}).get('asin')
    if asin is None:
        continue  # Skip if asin is missing

    for review in result.get('content', {}).get('reviews', []):
        count1 += 1
        try:
            review_info1 = {
                'review_id': review.get('id'),
                'product_id': asin,
                'title': review.get('title'),
                'author': review.get('author'),
                'rating': review.get('rating'),
                'content': review.get('content'),
                'timestamp': review.get('timestamp'),
                'profile_id': review.get('profile_id'),
                'is_verified': review.get('is_verified', False),
                'helpful_count': review.get('helpful_count', 0),
                'product_attributes': review.get('product_attributes', {}),
            }
            reviews_data1.append(review_info1)
        except KeyError as e:
            print(f"KeyError at review {count1}: {e}")
        except Exception as e:
            print(f"Error at review {count1}: {e}")

if reviews_data1:
    reviews_df1 = pd.DataFrame(reviews_data1)
else:
    print("No reviews data available.")

# %%
reviews_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           70 non-null     object
#  1   product_id          70 non-null     object
#  2   title               70 non-null     object
#  3   author              70 non-null     object
#  4   rating              70 non-null     int64
#  5   content             70 non-null     object
#  6   timestamp           70 non-null     object
#  7   profile_id          70 non-null     object
#  8   is_verified         70 non-null     bool
#  9   helpful_count       70 non-null     int64
#  10  product_attributes  70 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 5.7+ KB

# %%
reviews_df1.head()
# Out:
#         review_id  product_id  \
# 0   RTLA4BSYTVDXW  B01CQOV3YO
# 1  R261JPWOR8SMHQ  B01CQOV3YO
# 2   R78L5493ANQZ2  B01CQOV3YO
# 3  R10H7FXGP9CE81  B01CQOV3YO
# 4  R2ERP05SNTZ1A0  B01CQOV3YO
#
#                                                title              author  \
# 0       1.0 out of 5 stars Sound quality is lacking.                 Bob
# 1       5.0 out of 5 stars Customer Service is GREAT         Jim Rollins
# 2  5.0 out of 5 stars Has worked perfectly for a ...                Jeff
# 3               5.0 out of 5 stars best speaker ever   Kirkpatrick House
# 4  1.0 out of 5 stars Bluetooth connection stutte...  salute_to_veterans
#
#    rating                                            content  \
# 0       1  The build quality of this unit is very good. H...
# 1       5  I had a problem with my player and it was repl...
# 2       5  It’s small but is loud enough for where I use ...
# 3       5                                  5 stars Read more
# ...

# %%
file_path2 = '/content/doss_soundbox_touch_blue_data.json'
with open(file_path2, 'r') as file:
    data2 = json.load(file)

# %%
reviews_data2 = []
count2 = 0

for result in data2.get('results', []):
    asin = result.get('content', {}).get('asin')
    if asin is None:
        continue  # Skip if asin is missing

    for review in result.get('content', {}).get('reviews', []):
        count2 += 1
        try:
            review_info2 = {
                'review_id': review.get('id'),
                'product_id': asin,
                'title': review.get('title'),
                'author': review.get('author'),
                'rating': review.get('rating'),
                'content': review.get('content'),
                'timestamp': review.get('timestamp'),
                'profile_id': review.get('profile_id'),
                'is_verified': review.get('is_verified', False),
                'helpful_count': review.get('helpful_count', 0),
                'product_attributes': review.get('product_attributes', {}),
            }
            reviews_data2.append(review_info2)
        except KeyError as e:
            print(f"KeyError at review {count2}: {e}")
        except Exception as e:
            print(f"Error at review {count2}: {e}")

if reviews_data2:
    reviews_df2 = pd.DataFrame(reviews_data2)
else:
    print("No reviews data available.")

# %%
reviews_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           49 non-null     object
#  1   product_id          49 non-null     object
#  2   title               49 non-null     object
#  3   author              49 non-null     object
#  4   rating              49 non-null     int64
#  5   content             49 non-null     object
#  6   timestamp           49 non-null     object
#  7   profile_id          49 non-null     object
#  8   is_verified         49 non-null     bool
#  9   helpful_count       49 non-null     int64
#  10  product_attributes  49 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 4.0+ KB

# %%
reviews_df2.head()
# Out:
#         review_id  product_id  \
# 0   RTLA4BSYTVDXW  B01CRPV4UK
# 1  R261JPWOR8SMHQ  B01CRPV4UK
# 2   R78L5493ANQZ2  B01CRPV4UK
# 3  R10H7FXGP9CE81  B01CRPV4UK
# 4  R2ERP05SNTZ1A0  B01CRPV4UK
#
#                                                title              author  \
# 0       1.0 out of 5 stars Sound quality is lacking.                 Bob
# 1       5.0 out of 5 stars Customer Service is GREAT         Jim Rollins
# 2  5.0 out of 5 stars Has worked perfectly for a ...                Jeff
# 3               5.0 out of 5 stars best speaker ever   Kirkpatrick House
# 4  1.0 out of 5 stars Bluetooth connection stutte...  salute_to_veterans
#
#    rating                                            content  \
# 0       1  The build quality of this unit is very good. H...
# 1       5  I had a problem with my player and it was repl...
# 2       5  It’s small but is loud enough for where I use ...
# 3       5                                  5 stars Read more
# ...

# %%
combined_df = pd.concat([reviews_df1, reviews_df2], ignore_index=True)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           119 non-null    object
#  1   product_id          119 non-null    object
#  2   title               119 non-null    object
#  3   author              119 non-null    object
#  4   rating              119 non-null    int64
#  5   content             119 non-null    object
#  6   timestamp           119 non-null    object
#  7   profile_id          119 non-null    object
#  8   is_verified         119 non-null    bool
#  9   helpful_count       119 non-null    int64
#  10  product_attributes  119 non-null    object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 9.5+ KB

# %%
combined_df.head()
# Out:
#         review_id  product_id  \
# 0   RTLA4BSYTVDXW  B01CQOV3YO
# 1  R261JPWOR8SMHQ  B01CQOV3YO
# 2   R78L5493ANQZ2  B01CQOV3YO
# 3  R10H7FXGP9CE81  B01CQOV3YO
# 4  R2ERP05SNTZ1A0  B01CQOV3YO
#
#                                                title              author  \
# 0       1.0 out of 5 stars Sound quality is lacking.                 Bob
# 1       5.0 out of 5 stars Customer Service is GREAT         Jim Rollins
# 2  5.0 out of 5 stars Has worked perfectly for a ...                Jeff
# 3               5.0 out of 5 stars best speaker ever   Kirkpatrick House
# 4  1.0 out of 5 stars Bluetooth connection stutte...  salute_to_veterans
#
#    rating                                            content  \
# 0       1  The build quality of this unit is very good. H...
# 1       5  I had a problem with my player and it was repl...
# 2       5  It’s small but is loud enough for where I use ...
# 3       5                                  5 stars Read more
# ...

# %%
#combined_df.to_csv('doss_soundbox_data.csv', index=False)
